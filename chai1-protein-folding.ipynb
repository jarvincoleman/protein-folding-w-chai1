# %%
import os
if os.path.exists("/kaggle/working/protein-folding-w-chai1"):
    # !git -C /kaggle/working/protein-folding-w-chai1 pull
else:
    # !git clone https://github.com/jarvincoleman/protein-folding-w-chai1.git  /kaggle/working/protein-folding-w-chai1

# %%
# !pip install chai_lab py3Dmol -q

# %%
# !python /kaggle/working/protein-folding-w-chai1/chaii.py

# %%
import py3Dmol

cif_text = open("/kaggle/working/outputs/pred.model_idx_0.cif").read()

view = py3Dmol.view(width=800, height=600)
view.addModel(cif_text, "cif")
view.setStyle({"cartoon": {"color": "spectrum"}})
view.zoomTo()
view.show()
